# %%
pip install azure-storage-blob
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import requests
import json

url = "https://practicas6336904464.blob.core.windows.net/diplomadodc/jsonData.json"

response = requests.get(url)

if response.status_code == 200:
  json_data = response.json()
  print(json_data)
else:
  print("Error al obtener el archivo JSON:", response.status_code)
# Out:
# {'edoMex': [{'tipo': '3', 'titulo': 'nombre_estacion', 'nombre': 'VALLE DE BRAVO', 'url': 'https://practicas6336904464.blob.core.windows.net/diplomadodc/data/Valle_utf8.xlsx'}, {'tipo': '3', 'titulo': 'nombre_estacion', 'nombre': 'ATLACOMULCO', 'url': 'https://practicas6336904464.blob.core.windows.net/diplomadodc/data/Atlacomulco_utf8.xlsx'}, {'tipo': '3', 'titulo': 'nombre_estacion', 'nombre': 'Toluca', 'url': 'https://practicas6336904464.blob.core.windows.net/diplomadodc/data/Toluca_utf8.xlsx'}, {'tipo': '3', 'titulo': 'nombre_estacion', 'nombre': 'NEVADO DE TOLUCA', 'url': 'https://practicas6336904464.blob.core.windows.net/diplomadodc/data/nevado.xlsx'}, {'tipo': '3', 'titulo': 'nombre_estacion', 'nombre': 'LAGUNAS DE ZEMPOALA', 'url': 'https://practicas6336904464.blob.core.windows.net/diplomadodc/data/laguna.xlsx'}, {'tipo': '3', 'titulo': 'nombre_estacion', 'nombre': 'CERRO CATEDRAL', 'url': 'https://practicas6336904464.blob.core.windows.net/diplomadodc/data/cerro.xlsx'}, {'tipo
# ...

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

#Para poder ejecutarlo, pasen el archivo jsonData.json a una ubicación dentro de Mi unidad, en sus carpetas personales
#       y cambien la ruda de jsonDatos
# jsonDatos = "/content/drive/MyDrive/Proyecto DSCAD/jsonData.json"
jsonDatos = "https://practicas6336904464.blob.core.windows.net/diplomadodc/jsonData.json"
url = "https://smn.conagua.gob.mx/tools/GUI/sivea_v3/php/getReporteEstacion.php"

# with open(jsonDatos, 'r') as file:
#     data = json.load(file)

for item in json_data["edoMex"]:
  params = {'tipo': item["tipo"], item["titulo"]: item["nombre"]}
  response = requests.get(url, params=params)

  if response.status_code == 200:
    nombre_archivo = response.headers.get('Content-Disposition').split('=')[1]
    with open(nombre_archivo, 'wb') as archivo:
        archivo.write(response.content)
    print(f'Descarga exitosa. Archivo guardado como: {nombre_archivo}')
  else:
    print(f'Error en la solicitud. Código de estado: {response.status_code}')
# Out:
# Descarga exitosa. Archivo guardado como: Estacion_VALLE DE BRAVO_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_ATLACOMULCO_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_Toluca_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_NEVADO DE TOLUCA_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_LAGUNAS DE ZEMPOALA_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_CERRO CATEDRAL_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_PRESA MADIN_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_IXTAPALUCA_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_MANUEL AVILA CAMACHO_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_ALTZOMONI_90_dias.xlsx
# Descarga exitosa. Archivo guardado como: Estacion_PARQUE IXTA POPO_90_dias.xlsx

# %%
# prompt: quiero listar todos los archivos de la carpta archivos de colab

# !ls /content
# Out:
#  Estacion_ALTZOMONI_90_dias.xlsx	      'Estacion_NEVADO DE TOLUCA_90_dias.xlsx'
#  Estacion_ATLACOMULCO_90_dias.xlsx	      'Estacion_PARQUE IXTA POPO_90_dias.xlsx'
# 'Estacion_CERRO CATEDRAL_90_dias.xlsx'	      'Estacion_PRESA MADIN_90_dias.xlsx'
#  Estacion_IXTAPALUCA_90_dias.xlsx	       Estacion_Toluca_90_dias.xlsx
# 'Estacion_LAGUNAS DE ZEMPOALA_90_dias.xlsx'   'Estacion_VALLE DE BRAVO_90_dias.xlsx'
# 'Estacion_MANUEL AVILA CAMACHO_90_dias.xlsx'   sample_data

# %%
# !pip install openpyxl

# %%
# !rm -f *.xlsx
